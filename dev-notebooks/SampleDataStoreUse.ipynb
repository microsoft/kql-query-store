# %%
import sys
import json
from pathlib import Path


if ".." not in sys.path:
    sys.path.append("..")

from src.data_store import DataStore

# %% [markdown]
# ## Create store from JSON

# %%
_TEST_JSON = "../test_runs/kql_query_db-022-09-23_00_44_55.json"

ds = DataStore(json_path=_TEST_JSON)

# %% [markdown]
# ## Simple OPs

# %%
# queries brings the whole set back as a list
print(ds.queries[3], "\n")

# also get the whole set as JSON or DF
print("\nJSON\n", ds.to_json()[:300], "\n")
ds.to_df().head(3)
# Out:
# KqlQuery(source_path='https://github.com/Azure/Azure-Sentinel/blob/master/Detections%5CASimAuthentication%5CimAuthSigninsMultipleCountries.yaml', query="let timeframe = ago(3h);\nlet threshold = 2;\nimAuthentication\n| where TimeGenerated > timeframe\n| where EventType=='Logon' and EventResult=='Success'\n| where isnotempty(SrcGeoCountry)\n| summarize StartTime = min(TimeGenerated), EndTime = max(TimeGenerated), Vendors=make_set(EventVendor), Products=make_set(EventProduct)\n  , NumOfCountries = dcount(SrcGeoCountry)\n  by TargetUserId, TargetUsername, TargetUserType\n| where NumOfCountries >= threshold\n| extend timestamp = StartTime, AccountCustomEntity = TargetUsername\n", source_type='text', source_index=0, repo_name='Azure/Azure-Sentinel', query_name='User login from different countries within 3 hours (Uses Authentication Normalization)', context=None, attributes={'description': "'This query searches for successful user logins from different countries within 3 hours.\n To use this analytics rule, make sure you have deployed the [ASIM normalization parsers](https://aka.ms/ASimAuthentication)'\n", 'techniques': ['T1078'], 'tactics': ['InitialAccess']}, kql_properties={'functioncalls': ['ago', 'isnotempty', 'min', 'max', 'make_set', 'dcount'], 'joins': {}, 'operators': ['where', 'summarize', 'extend'], 'tables': ['imAuthentication']}, query_id='9e569474-e0e8-4281-8a4d-7b14bba0b681', query_hash='47f3cf5bb4056439bb8e18ca4624c0ec2e8043ad62fb460d42756b0f14f1a158', query_version=0)
#
#
# JSON
#  [{"source_path": "https://github.com/Azure/Azure-Sentinel/blob/master/Detections%5CAnomalies%5CUnusualAnomaly.yaml", "query": "// You can leave out Anomalies that are already monitored through other Analytics Rules\n//let _MonitoredRules = dynamic([\"TestAlertName\"]);\nlet query_frequency = 1h;\nle
#                                          source_path  \
# 0  https://github.com/Azure/Azure-Sentinel/blob/m...
# 1  https://github.com/Azure/Azure-Sentinel/blob/m...
# 2  https://github.com/Azure/Azure-Sentinel/blob/m...
#
#                                                query source_type  \
# 0  // You can leave out Anomalies that are alread...        text
# 1  let failureCountThreshold = 10;\nlet successCo...        text
# 2  let FailureThreshold = 15;\nimAuthentication\n...        text
#
#    source_index             repo_name  \
# 0             0  Azure/Azure-Sentinel
# 1             0  Azure/Azure-Sentinel
# 2             0  Azure/Azure-Sentinel
#
#                                           query_name context  \
# 0                                    Unusual Anomaly    None
# 1  Brute force attack against user credentials (U...    None
# 2  Potential Password Spray Attack (Uses Authenti...    None
#
#                                           attributes  \
# 0  {'description': ''Anomaly Rules generate event...
# 1  {'description': ''Identifies evidence of brute...
# 2  {'description': ''This query searches for fail...
#
#                                       kql_properties  \
# 0  {'functioncalls': ['ago'], 'joins': {' leftant...
# 1  {'functioncalls': ['min', 'max', 'make_set', '...
# 2  {'functioncalls': ['dcount', 'make_set', 'bin'...
#
#                                query_id  \
# 0  72515608-2800-439c-9f39-43743f9a76e2
# 1  829a30db-2608-4784-a29d-c2e6dd058db6
# 2  86f97790-8c45-40b5-b76e-c2410a517b15
#
#                                           query_hash  query_version
# 0  a81433962b6dd7226deb5f1e7c8761af9ab6ef9d6217f0...              0
# 1  7983ad26e75cb7525c70235533555ba8047164e6cfd74b...              0
# 2  cc33ae898a65f31fd97da32adc2d389cac996905b90cd3...              0

# %% [markdown]
# ## Get lists of attributes for filter controls

# %%
# 
ds.get_filter_lists()

# show approx items
print("indexes:")
print([f"{filter}: items: {len(vals)}" for filter, vals in ds.get_filter_lists().items()])
print("\nValues for 'operators' index")
print(ds.get_filter_lists()["operators"])
# Out:
# indexes:
# ['tactics: items: 35', 'techniques: items: 192', 'tables: items: 980', 'operators: items: 29', 'functioncalls: items: 203', 'joins: items: 0']
#
# Values for 'operators' index
# ['as', 'count', 'distinct', 'evaluate', 'extend', 'filter', 'invoke', 'limit', 'make-series', 'mv-apply', 'mv-expand', 'mvexpand', 'order', 'parse', 'parse-where', 'partition', 'project', 'project-away', 'project-rename', 'project-reorder', 'render', 'serialize', 'sort', 'summarize', 'take', 'top', 'top-nested', 'union', 'where']

# %% [markdown]
# ## Queries

# %%
# queries
# You can query on any field with "field=value"
# Simple query must be exact match
result = ds.find_queries(
    query_name="User login from different countries within 3 hours (Uses Authentication Normalization)"
)
print(result.shape)
display(result.head(3))
# Out:
# (1, 11)
#                                                                             source_path  \
# query_id
# 9e569474-e0e8-4281-8a4d-7b14bba0b681  https://github.com/Azure/Azure-Sentinel/blob/m...
#
#                                                                                   query  \
# query_id
# 9e569474-e0e8-4281-8a4d-7b14bba0b681  let timeframe = ago(3h);\nlet threshold = 2;\n...
#
#                                      source_type  source_index  \
# query_id
# 9e569474-e0e8-4281-8a4d-7b14bba0b681        text             0
#
#                                                  repo_name  \
# query_id
# 9e569474-e0e8-4281-8a4d-7b14bba0b681  Azure/Azure-Sentinel
#
#                                                                              query_name  \
# query_id
# 9e569474-e0e8-4281-8a4d-7b14bba0b681  User login from different countries within 3 h...
#
#                                      context  \
# query_id
# 9e569474-e0e8-4281-8a4d-7b14bba0b681    None
#
#                                                                              attributes  \
# query_id
# 9e569474-e0e8-4281-8a4d-7b14bba0b681  {'description': ''This query searches for succ...
#
#                                                                          kql_properties  \
# query_id
# 9e569474-e0e8-4281-8a4d-7b14bba0b681  {'functioncalls': ['ago', 'isnotempty', 'min',...
#
#                                                                              query_hash  \
# query_id
# 9e569474-e0e8-4281-8a4d-7b14bba0b681  47f3cf5bb4056439bb8e18ca4624c0ec2e8043ad62fb46...
#
#                                       query_version
# query_id
# 9e569474-e0e8-4281-8a4d-7b14bba0b681              0

# %%
result = ds.find_queries(query_name={"contains": "user"})
print(result.shape)
display(result.head(3))
# Out:
# (389, 11)
#                                                                             source_path  \
# query_id
# 829a30db-2608-4784-a29d-c2e6dd058db6  https://github.com/Azure/Azure-Sentinel/blob/m...
# 9e569474-e0e8-4281-8a4d-7b14bba0b681  https://github.com/Azure/Azure-Sentinel/blob/m...
# 99259dd8-acbf-41a6-b304-4325526276f2  https://github.com/Azure/Azure-Sentinel/blob/m...
#
#                                                                                   query  \
# query_id
# 829a30db-2608-4784-a29d-c2e6dd058db6  let failureCountThreshold = 10;\nlet successCo...
# 9e569474-e0e8-4281-8a4d-7b14bba0b681  let timeframe = ago(3h);\nlet threshold = 2;\n...
# 99259dd8-acbf-41a6-b304-4325526276f2  let known_users = (AuditLogs\n  | where TimeGe...
#
#                                      source_type  source_index  \
# query_id
# 829a30db-2608-4784-a29d-c2e6dd058db6        text             0
# 9e569474-e0e8-4281-8a4d-7b14bba0b681        text             0
# 99259dd8-acbf-41a6-b304-4325526276f2        text             0
#
#                                                  repo_name  \
# query_id
# 829a30db-2608-4784-a29d-c2e6dd058db6  Azure/Azure-Sentinel
# 9e569474-e0e8-4281-8a4d-7b14bba0b681  Azure/Azure-Sentinel
# 99259dd8-acbf-41a6-b304-4325526276f2  Azure/Azure-Sentinel
#
#                                                                              query_name  \
# query_id
# 829a30db-2608-4784-a29d-c2e6dd058db6  Brute force attack against user credentials (U...
# 9e569474-e0e8-4281-8a4d-7b14bba0b681  User login from different countries within 3 h...
# 99259dd8-acbf-41a6-b304-4325526276f2     Conditional Access Policy Modified by New User
#
#                                      context  \
# query_id
# 829a30db-2608-4784-a29d-c2e6dd058db6    None
# 9e569474-e0e8-4281-8a4d-7b14bba0b681    None
# 99259dd8-acbf-41a6-b304-4325526276f2    None
#
#                                                                              attributes  \
# query_id
# 829a30db-2608-4784-a29d-c2e6dd058db6  {'description': ''Identifies evidence of brute...
# 9e569474-e0e8-4281-8a4d-7b14bba0b681  {'description': ''This query searches for succ...
# 99259dd8-acbf-41a6-b304-4325526276f2  {'description': ''Detects a Conditional Access...
#
#                                                                          kql_properties  \
# query_id
# 829a30db-2608-4784-a29d-c2e6dd058db6  {'functioncalls': ['min', 'max', 'make_set', '...
# 9e569474-e0e8-4281-8a4d-7b14bba0b681  {'functioncalls': ['ago', 'isnotempty', 'min',...
# 99259dd8-acbf-41a6-b304-4325526276f2  {'functioncalls': ['ago', 'tostring', 'parse_j...
#
#                                                                              query_hash  \
# query_id
# 829a30db-2608-4784-a29d-c2e6dd058db6  7983ad26e75cb7525c70235533555ba8047164e6cfd74b...
# 9e569474-e0e8-4281-8a4d-7b14bba0b681  47f3cf5bb4056439bb8e18ca4624c0ec2e8043ad62fb46...
# 99259dd8-acbf-41a6-b304-4325526276f2  246e62532d502dc18e3c859dc48a71264fca9091c88231...
#
#                                       query_version
# query_id
# 829a30db-2608-4784-a29d-c2e6dd058db6              0
# 9e569474-e0e8-4281-8a4d-7b14bba0b681              0
# 99259dd8-acbf-41a6-b304-4325526276f2              0

# %%
# multiple conditions are ANDed - i.e. all must be true
result = ds.find_queries(
    query_name={"contains": "user"},
    repo_name={"contains": "reprise99"}
)
print(result.shape)
display(result.head(3))
# Out:
# (68, 11)
#                                                                             source_path  \
# query_id
# 539ef59d-001b-4409-a4ac-aa37caaac682  https://github.com/reprise99/Sentinel-Queries/...
# 48099407-8a8c-4927-8027-a20492f871ab  https://github.com/reprise99/Sentinel-Queries/...
# a2e159e6-3819-4045-b760-9236c18b5154  https://github.com/reprise99/Sentinel-Queries/...
#
#                                                                                   query  \
# query_id
# 539ef59d-001b-4409-a4ac-aa37caaac682  //Detects when unconstrained kerberos delegati...
# 48099407-8a8c-4927-8027-a20492f871ab  //When a user holding a privileged role trigge...
# a2e159e6-3819-4045-b760-9236c18b5154  //Find users who have failed 3 or more times t...
#
#                                      source_type  source_index  \
# query_id
# 539ef59d-001b-4409-a4ac-aa37caaac682        text             0
# 48099407-8a8c-4927-8027-a20492f871ab        text             0
# a2e159e6-3819-4045-b760-9236c18b5154        text             0
#
#                                                        repo_name  \
# query_id
# 539ef59d-001b-4409-a4ac-aa37caaac682  reprise99/Sentinel-Queries
# 48099407-8a8c-4927-8027-a20492f871ab  reprise99/Sentinel-Queries
# a2e159e6-3819-4045-b760-9236c18b5154  reprise99/Sentinel-Queries
#
#                                                                        query_name  \
# query_id
# 539ef59d-001b-4409-a4ac-aa37caaac682  SecurityEvent-UnconstrainedDelegationtoUser
# 48099407-8a8c-4927-8027-a20492f871ab            Audit-EventsbyRiskyPrivilegedUser
# a2e159e6-3819-4045-b760-9236c18b5154        Audit-FindUsersFailingNewPasswordSSPR
#
#                                      context attributes  \
# query_id
# 539ef59d-001b-4409-a4ac-aa37caaac682    None         {}
# 48099407-8a8c-4927-8027-a20492f871ab    None         {}
# a2e159e6-3819-4045-b760-9236c18b5154    None         {}
#
#                                                                          kql_properties  \
# query_id
# 539ef59d-001b-4409-a4ac-aa37caaac682  {'functioncalls': [], 'joins': {}, 'operators'...
# 48099407-8a8c-4927-8027-a20492f871ab  {'functioncalls': ['ago', 'arg_max', 'isnotemp...
# a2e159e6-3819-4045-b760-9236c18b5154  {'functioncalls': ['tostring', 'parse_json', '...
#
#                                                                              query_hash  \
# query_id
# 539ef59d-001b-4409-a4ac-aa37caaac682  4bc453f54e846116d50edd8391b46c405d619900c5c3b5...
# 48099407-8a8c-4927-8027-a20492f871ab  bf294f42b09368f5695b4cb3c48a2e4a281f9160dd9a7e...
# a2e159e6-3819-4045-b760-9236c18b5154  531e6fd0d3b41f2fb826c9f0765d3f40241fa874a74086...
#
#                                       query_version
# query_id
# 539ef59d-001b-4409-a4ac-aa37caaac682              0
# 48099407-8a8c-4927-8027-a20492f871ab              0
# a2e159e6-3819-4045-b760-9236c18b5154              0

# %%
# Find all queries that have "user" in the name
# and use either SigninLogs or AuditLogs
result = ds.find_queries(
    query_name={"contains": "user"},
    tables=["SecurityAlert"] # the list values are OR'd - so will return UNION of matches
)
print(result.shape)
display(result.head(3))
# Out:
# (9, 11)
#                                                                             source_path  \
# query_id
# 0d8ad554-e6db-4080-8835-2c8738cad27b  https://github.com/Azure/Azure-Sentinel/blob/m...
# 3af3f86e-e3a2-4c62-9da4-8433219b6efd  https://github.com/Azure/Azure-Sentinel/blob/m...
# 83ad1ff3-04ee-4406-8877-832eed30c03f  https://github.com/Azure/Azure-Sentinel/blob/m...
#
#                                                                                   query  \
# query_id
# 0d8ad554-e6db-4080-8835-2c8738cad27b  // Set the lookback to determine if user has c...
# 3af3f86e-e3a2-4c62-9da4-8433219b6efd  let Alerts = SecurityAlert\n| where AlertName ...
# 83ad1ff3-04ee-4406-8877-832eed30c03f  let AlertLinks = SecurityAlert\n| summarize hi...
#
#                                      source_type  source_index  \
# query_id
# 0d8ad554-e6db-4080-8835-2c8738cad27b        text             0
# 3af3f86e-e3a2-4c62-9da4-8433219b6efd        text             0
# 83ad1ff3-04ee-4406-8877-832eed30c03f        text             0
#
#                                                  repo_name  \
# query_id
# 0d8ad554-e6db-4080-8835-2c8738cad27b  Azure/Azure-Sentinel
# 3af3f86e-e3a2-4c62-9da4-8433219b6efd  Azure/Azure-Sentinel
# 83ad1ff3-04ee-4406-8877-832eed30c03f  Azure/Azure-Sentinel
#
#                                                                              query_name  \
# query_id
# 0d8ad554-e6db-4080-8835-2c8738cad27b      Azure DevOps Pipeline modified by a new user.
# 3af3f86e-e3a2-4c62-9da4-8433219b6efd  Mass Download & copy to USB device by single user
# 83ad1ff3-04ee-4406-8877-832eed30c03f  Insider Risk_High User Security Alert Correlat...
#
#                                      context  \
# query_id
# 0d8ad554-e6db-4080-8835-2c8738cad27b    None
# 3af3f86e-e3a2-4c62-9da4-8433219b6efd    None
# 83ad1ff3-04ee-4406-8877-832eed30c03f    None
#
#                                                                              attributes  \
# query_id
# 0d8ad554-e6db-4080-8835-2c8738cad27b  {'description': ''There are several potential ...
# 3af3f86e-e3a2-4c62-9da4-8433219b6efd  {'description': ''This query looks for any mas...
# 83ad1ff3-04ee-4406-8877-832eed30c03f  {'description': ''This alert joins SecurityAle...
#
#                                                                          kql_properties  \
# query_id
# 0d8ad554-e6db-4080-8835-2c8738cad27b  {'functioncalls': ['ago', 'strcat', 'tolower',...
# 3af3f86e-e3a2-4c62-9da4-8433219b6efd  {'functioncalls': ['parse_json', 'tostring', '...
# 83ad1ff3-04ee-4406-8877-832eed30c03f  {'functioncalls': ['arg_max', 'count', 'todyna...
#
#                                                                              query_hash  \
# query_id
# 0d8ad554-e6db-4080-8835-2c8738cad27b  3ba73c49ac0a16ee6bd2af956146b80803ff322e87e650...
# 3af3f86e-e3a2-4c62-9da4-8433219b6efd  697fbd3e51e58c50f6696962f59f9ee1a55fe7dd832630...
# 83ad1ff3-04ee-4406-8877-832eed30c03f  8325412d12fad27c162597020aa9fd5a1a811a4112a955...
#
#                                       query_version
# query_id
# 0d8ad554-e6db-4080-8835-2c8738cad27b              0
# 3af3f86e-e3a2-4c62-9da4-8433219b6efd              0
# 83ad1ff3-04ee-4406-8877-832eed30c03f              0

# %%
# Bad property name will throw exception
display(
    ds.find_queries(
        query_name={"contains": "user"},
        table=["SigninLogs", "AuditLogs"], # the list values are OR'd - so will return UNION
        operator=["mv-expand", "distinct"] # the list values are OR'd - so will return UNION
    ).shape
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_222004\3143422731.py in <module>
#       1 # Bad property name will throw exception
#       2 display(
# ----> 3     ds.find_queries(
#       4         query_name={"contains": "user"},
#       5         table=["SigninLogs", "AuditLogs"], # the list values are OR'd - so will return UNION
#
# e:\src\kql-query-store\dev-notebooks\..\src\data_store.py in find_queries(self, case, **kwargs)
#     198         for arg_name, arg_expr in kwargs.items():
#     199             if arg_name not in valid_fields:
# --> 200                 raise ValueError(
#     201                     f"Unknown attribute name {arg_name}",
#     202                     f"Search expression: {arg_expr}."
#
# ValueError: Unknown attribute name {arg_name

# %%
# multiple filters
result = ds.find_queries(
    query_name={"contains": "user"},
    tables=["SigninLogs", "AuditLogs"], # the list values are OR'd - so will return UNION
    operators=["mv-expand", "distinct"] # the list values are OR'd - so will return UNION
)
print(result.shape)
display(result.head(3))
# Out:
# (27, 11)
#                                                                             source_path  \
# query_id
# 5688beda-11f4-41ce-bdeb-024d05ccaee2  https://github.com/Azure/Azure-Sentinel/blob/m...
# 74d08c7b-3630-4a28-8fba-9cd0460ea75c  https://github.com/Azure/Azure-Sentinel/blob/m...
# cb3aa662-6fbc-46ef-9776-b3266338a725  https://github.com/Azure/Azure-Sentinel/blob/m...
#
#                                                                                   query  \
# query_id
# 5688beda-11f4-41ce-bdeb-024d05ccaee2  AuditLogs\n  | where OperationName has "Consen...
# 74d08c7b-3630-4a28-8fba-9cd0460ea75c  // Administrative roles to look for, default i...
# cb3aa662-6fbc-46ef-9776-b3266338a725  let lookback = 1d;\nAuditLogs \n| where TimeGe...
#
#                                      source_type  source_index  \
# query_id
# 5688beda-11f4-41ce-bdeb-024d05ccaee2        text             0
# 74d08c7b-3630-4a28-8fba-9cd0460ea75c        text             0
# cb3aa662-6fbc-46ef-9776-b3266338a725        text             0
#
#                                                  repo_name  \
# query_id
# 5688beda-11f4-41ce-bdeb-024d05ccaee2  Azure/Azure-Sentinel
# 74d08c7b-3630-4a28-8fba-9cd0460ea75c  Azure/Azure-Sentinel
# cb3aa662-6fbc-46ef-9776-b3266338a725  Azure/Azure-Sentinel
#
#                                                                              query_name  \
# query_id
# 5688beda-11f4-41ce-bdeb-024d05ccaee2  End-user consent stopped due to risk-based con...
# 74d08c7b-3630-4a28-8fba-9cd0460ea75c                    New External User Granted Admin
# cb3aa662-6fbc-46ef-9776-b3266338a725  Suspicious linking of existing user to externa...
#
#                                      context  \
# query_id
# 5688beda-11f4-41ce-bdeb-024d05ccaee2    None
# 74d08c7b-3630-4a28-8fba-9cd0460ea75c    None
# cb3aa662-6fbc-46ef-9776-b3266338a725    None
#
#                                                                              attributes  \
# query_id
# 5688beda-11f4-41ce-bdeb-024d05ccaee2  {'description': ''Detects a user's consent to ...
# 74d08c7b-3630-4a28-8fba-9cd0460ea75c  {'description': ''This query will detect insta...
# cb3aa662-6fbc-46ef-9776-b3266338a725  {'description': '' This query will detect when...
#
#                                                                          kql_properties  \
# query_id
# 5688beda-11f4-41ce-bdeb-024d05ccaee2  {'functioncalls': ['tostring', 'parse_json', '...
# 74d08c7b-3630-4a28-8fba-9cd0460ea75c  {'functioncalls': ['tostring', 'isnotempty', '...
# cb3aa662-6fbc-46ef-9776-b3266338a725  {'functioncalls': ['ago', 'tostring', 'parse_j...
#
#                                                                              query_hash  \
# query_id
# 5688beda-11f4-41ce-bdeb-024d05ccaee2  e404742d11c204305d69d24a82e908c84103d20686a558...
# 74d08c7b-3630-4a28-8fba-9cd0460ea75c  dff2d92ed33d9fe6e4f517e19935aeafd69f1ca6a9794e...
# cb3aa662-6fbc-46ef-9776-b3266338a725  8ee32ee5daacf323516f5e178ffbbdb2510c39a67439e7...
#
#                                       query_version
# query_id
# 5688beda-11f4-41ce-bdeb-024d05ccaee2              0
# 74d08c7b-3630-4a28-8fba-9cd0460ea75c              0
# cb3aa662-6fbc-46ef-9776-b3266338a725              0

# %%
# Use debug=True to get more insight into which item is matching what.
result = ds.find_queries(
    query_name={"contains": "user"},
    tables=["SigninLogs", "AuditLogs"], # the list values are OR'd - so will return UNION
    operators=["mv-expand", "distinct"], # the list values are OR'd - so will return UNION
    debug=True,
)
print(result.shape)
display(result.head(3))
# Out:
# {'contains': 'user'} False    2517
# True      389
# Name: query_name, dtype: int64
# 202
# 197
# ['SigninLogs', 'AuditLogs'] False    2814
# True       92
# Name: query_name, dtype: int64
# 230
# 150
# ['mv-expand', 'distinct'] False    2879
# True       27
# Name: query_name, dtype: int64
# final criteria: False    2879
# True       27
# Name: query_name, dtype: int64
# (27, 11)
#                                                                             source_path  \
# query_id
# 5688beda-11f4-41ce-bdeb-024d05ccaee2  https://github.com/Azure/Azure-Sentinel/blob/m...
# 74d08c7b-3630-4a28-8fba-9cd0460ea75c  https://github.com/Azure/Azure-Sentinel/blob/m...
# cb3aa662-6fbc-46ef-9776-b3266338a725  https://github.com/Azure/Azure-Sentinel/blob/m...
#
#                                                                                   query  \
# query_id
# 5688beda-11f4-41ce-bdeb-024d05ccaee2  AuditLogs\n  | where OperationName has "Consen...
# 74d08c7b-3630-4a28-8fba-9cd0460ea75c  // Administrative roles to look for, default i...
# cb3aa662-6fbc-46ef-9776-b3266338a725  let lookback = 1d;\nAuditLogs \n| where TimeGe...
#
#                                      source_type  source_index  \
# query_id
# 5688beda-11f4-41ce-bdeb-024d05ccaee2        text             0
# 74d08c7b-3630-4a28-8fba-9cd0460ea75c        text             0
# cb3aa662-6fbc-46ef-9776-b3266338a725        text             0
#
#                                                  repo_name  \
# query_id
# 5688beda-11f4-41ce-bdeb-024d05ccaee2  Azure/Azure-Sentinel
# 74d08c7b-3630-4a28-8fba-9cd0460ea75c  Azure/Azure-Sentinel
# cb3aa662-6fbc-46ef-9776-b3266338a725  Azure/Azure-Sentinel
#
#                                                                              query_name  \
# query_id
# 5688beda-11f4-41ce-bdeb-024d05ccaee2  End-user consent stopped due to risk-based con...
# 74d08c7b-3630-4a28-8fba-9cd0460ea75c                    New External User Granted Admin
# cb3aa662-6fbc-46ef-9776-b3266338a725  Suspicious linking of existing user to externa...
#
#                                      context  \
# query_id
# 5688beda-11f4-41ce-bdeb-024d05ccaee2    None
# 74d08c7b-3630-4a28-8fba-9cd0460ea75c    None
# cb3aa662-6fbc-46ef-9776-b3266338a725    None
#
#                                                                              attributes  \
# query_id
# 5688beda-11f4-41ce-bdeb-024d05ccaee2  {'description': ''Detects a user's consent to ...
# 74d08c7b-3630-4a28-8fba-9cd0460ea75c  {'description': ''This query will detect insta...
# cb3aa662-6fbc-46ef-9776-b3266338a725  {'description': '' This query will detect when...
#
#                                                                          kql_properties  \
# query_id
# 5688beda-11f4-41ce-bdeb-024d05ccaee2  {'functioncalls': ['tostring', 'parse_json', '...
# 74d08c7b-3630-4a28-8fba-9cd0460ea75c  {'functioncalls': ['tostring', 'isnotempty', '...
# cb3aa662-6fbc-46ef-9776-b3266338a725  {'functioncalls': ['ago', 'tostring', 'parse_j...
#
#                                                                              query_hash  \
# query_id
# 5688beda-11f4-41ce-bdeb-024d05ccaee2  e404742d11c204305d69d24a82e908c84103d20686a558...
# 74d08c7b-3630-4a28-8fba-9cd0460ea75c  dff2d92ed33d9fe6e4f517e19935aeafd69f1ca6a9794e...
# cb3aa662-6fbc-46ef-9776-b3266338a725  8ee32ee5daacf323516f5e178ffbbdb2510c39a67439e7...
#
#                                       query_version
# query_id
# 5688beda-11f4-41ce-bdeb-024d05ccaee2              0
# 74d08c7b-3630-4a28-8fba-9cd0460ea75c              0
# cb3aa662-6fbc-46ef-9776-b3266338a725              0
